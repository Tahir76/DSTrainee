# %%
# !pip install pandas
import pandas as pd
# Out:
# ...
#      ---------------------------------------- 10.9/10.9 MB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.9/14.9 MB 4.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 499.4/499.4 kB 5.2 MB/s eta 0:00:00
# ...

# %%
movies = pd.read_csv('movie.csv')

# %%
movies.shape
# Out:
# (4916, 22)

# %%
movies.head(20)
# Out:
#                                           title    year  color content_rating  \
# 0                                        Avatar  2009.0  Color          PG-13
# 1      Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 2                                       Spectre  2015.0  Color          PG-13
# 3                         The Dark Knight Rises  2012.0  Color          PG-13
# 4    Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# 5                                   John Carter  2012.0  Color          PG-13
# 6                                  Spider-Man 3  2007.0  Color          PG-13
# 7                                       Tangled  2010.0  Color             PG
# 8                       Avengers: Age of Ultron  2015.0  Color          PG-13
# 9        Harry Potter and the Half-Blood Prince  2009.0  Color             PG
# 10           Batman v Superman: Dawn of Justice  2016.0  Color          PG-13
# ...

# %%
movies.shape
# Out:
# (4916, 22)

# %% [markdown]
# Task#1
# Segregate movies with actors, imdb score more 6 less 8.1,

# %%
movies_cond= ['title','actor1','actor2','imdb_score']

# %%
movies_cond=movies[movies_cond]

# %%
based_on_ibmd = movies_cond[(movies_cond['imdb_score'] > 6) & (movies_cond['imdb_score'] <8.1)]

# %%
based_on_ibmd
# Out:
#                                            title           actor1  \
# 0                                         Avatar      CCH Pounder
# 1       Pirates of the Caribbean: At World's End      Johnny Depp
# 2                                        Spectre  Christoph Waltz
# 4     Star Wars: Episode VII - The Force Awakens      Doug Walker
# 5                                    John Carter     Daryl Sabara
# ...                                          ...              ...
# 4911                     Signed Sealed Delivered      Eric Mabius
# 4912                               The Following      Natalie Zea
# 4913                        A Plague So Pleasant      Eva Boehnke
# 4914                            Shanghai Calling        Alan Ruck
# 4915                           My Date with Drew      John August
#
#                 actor2  imdb_score
# 0     Joel David Moore         7.9
# 1        Orlando Bloom         7.1
# 2         Rory Kinnear         6.8
# ...

# %% [markdown]
# Task2#Segregate movies initial ten rows with condition actor2_fb less than 300 more than 11000

# %%
X= movies[(movies['actor2_fb']<300) | (movies['actor2_fb']>11000)]
X[['title','actor2_fb']].iloc[:10,:]
# Out:
#                                          title  actor2_fb
# 3                        The Dark Knight Rises    23000.0
# 4   Star Wars: Episode VII - The Force Awakens       12.0
# 8                      Avengers: Age of Ultron    21000.0
# 16    The Chronicles of Narnia: Prince Caspian      216.0
# 17                                The Avengers    21000.0
# 26                                     Titanic    14000.0
# 27                  Captain America: Civil War    19000.0
# 33                         Alice in Wonderland    25000.0
# 38                   Oz the Great and Powerful    15000.0
# 45                                   Furious 7    23000.0

# %% [markdown]
# Task3
# #Sort the data complete set by director names

# %%
sorted_director_names = movies.sort_values(by='director_name')

# %%
sorted_director_names
# Out:
#                     title    year  color content_rating  duration  \
# 4498  The Helix... Loaded  2005.0  Color              R      97.0
# 4221               Circle  2015.0  Color      Not Rated      87.0
# 3430              Get Low  2009.0  Color          PG-13     100.0
# 2156           Date Movie  2006.0  Color          PG-13      85.0
# 2862          The Funeral  1996.0  Color              R      99.0
# ...                   ...     ...    ...            ...       ...
# 4683               Heroes     NaN  Color          TV-14      60.0
# 4688          Home Movies     NaN  Color          TV-PG      22.0
# 4704           Revolution     NaN  Color          TV-14      43.0
# 4752         Happy Valley     NaN  Color          TV-MA      58.0
# 4912        The Following     NaN  Color          TV-14      43.0
#
#         director_name  director_fb               actor1  actor1_fb  \
# 4498    A. Raven Cruz          0.0           Scott Levy      639.0
# ...
